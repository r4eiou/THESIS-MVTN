# %%
import pandas as pd
import numpy as np

o = pd.read_csv('csv/NVGestures/original.csv', header = None, encoding='utf8') 



df1 = pd.read_csv('csv/NVGestures/train_nv_ir.csv', header = None, encoding='utf8') # place your csv1 in df1
df2 = pd.read_csv('csv/NVGestures/train_nv_normalrev.csv', header = None, encoding='utf8') # place your csv1 in df1
# df3 = pd.read_csv('csv/NVGestures/train_nv_depth+.csv', header = None, encoding='utf8') # place your csv1 in df1
df4 = pd.read_csv('csv/NVGestures/train_nv_normal+.csv', header = None, encoding='utf8') # place your csv1 in df1
# train_nv_depth
# df2 = pd.read_csv('csv/NVGestures/train_nv_depthrevwo.csv', header = None, encoding='utf8' ) # place your csv2 in df2
print((df1).shape)
print((df2).shape)
# print((df3).shape)
print((df4).shape)
# Out:
# (482, 25)
# (482, 26)
# (482, 26)

# %%
df2.head(10)
# Out:
#    0             1             2             3             4             5   \
# 0   0  6.977026e-01  1.019758e-05  3.022887e-06  3.650642e-07  2.819352e-01
# 1   0  9.999995e-01  1.873083e-08  2.681434e-07  1.698987e-07  3.979612e-09
# 2   0  9.795901e-01  1.497247e-06  9.989502e-04  4.548744e-05  4.774627e-07
# 3   0  9.994431e-01  1.598875e-06  7.655629e-06  5.050720e-05  1.974888e-07
# 4   0  9.999814e-01  1.709321e-07  6.841844e-07  7.842475e-06  2.588920e-08
# 5   0  3.492153e-07  9.995531e-01  8.313469e-08  2.420681e-07  2.191953e-08
# 6   0  1.598041e-06  8.702590e-01  6.192737e-07  1.573191e-06  6.398617e-08
# 7   0  4.035197e-05  6.027664e-01  2.369081e-06  3.992920e-05  1.552440e-06
# 8   0  1.427388e-07  9.999995e-01  1.568461e-09  2.383112e-09  1.657057e-10
# 9   0  9.999988e-01  7.251825e-08  5.114241e-08  1.020100e-06  3.945696e-09
#
#              6             7             8             9   ...            16  \
# ...

# %%
if df1.isna().any().any():
    print("DataFrame contains None values")
else:
    print("NO None values")
# Out:
# NO None values

# %%
# # new lines added
# split_data = df1[0].str.split(',', expand=False)
# df1 = pd.DataFrame(split_data.values.tolist())
# print((df1).shape)
split_data = df2[0].str.split(',', expand=False)
df2 = pd.DataFrame(split_data.values.tolist())
print((df2).shape)
if df2.isna().any().any():
    print("DataFrame contains None values")
else:
    print("NO None values")
df2.head()
# Out:
# (482, 25)
# DataFrame contains None values
#            0              1              2   \
# 0  0.99999976  2.7846061e-08   2.840848e-09
# 1   0.9999994  3.3055137e-08  1.7243702e-08
# 2   0.9999995  1.8080417e-08  6.4675736e-09
# 3  0.99999976  2.3466141e-08   2.176069e-09
# 4  0.99999976   2.606085e-08  2.2125222e-09
#
#                                                  3   \
# 0  1.3210812e-18.4400825e-19.895106e-11.6499841e-09
# 1              2.0764061e-18.186666e-11.6862342e-09
# 2                          1.2815447e-12.391914e-09
# 3                                      6.304554e-11
# 4                                      6.270113e-11
#
#                                       4                          5   \
# 0               5.3218757e-12.137777e-09  3.2205502e-12.5400597e-08
# 1                          5.6170775e-09  6.5149514e-14.2824184e-09
# 2               8.4047236e-14.455109e-09   6.2405137e-11.539489e-09
# ...

# %%
df2.head()
# Out:
#            0              1              2   \
# 0  0.99999976  2.7846061e-08   2.840848e-09
# 1   0.9999994  3.3055137e-08  1.7243702e-08
# 2   0.9999995  1.8080417e-08  6.4675736e-09
# 3  0.99999976  2.3466141e-08   2.176069e-09
# 4  0.99999976   2.606085e-08  2.2125222e-09
#
#                                                  3   \
# 0  1.3210812e-18.4400825e-19.895106e-11.6499841e-09
# 1              2.0764061e-18.186666e-11.6862342e-09
# 2                          1.2815447e-12.391914e-09
# 3                                      6.304554e-11
# 4                                      6.270113e-11
#
#                                       4                          5   \
# 0               5.3218757e-12.137777e-09  3.2205502e-12.5400597e-08
# 1                          5.6170775e-09  6.5149514e-14.2824184e-09
# 2               8.4047236e-14.455109e-09   6.2405137e-11.539489e-09
# 3  7.8552825e-15.2533367e-11.3723014e-09  3.8613818e-11.1687048e-09
# ...

# %%
print(df1[0].values.tolist())

#df2[df2.columns.drop('A')]

o1 = o.iloc[:,:].values.tolist() 
#print(type(o1))

rate_in_1 = df1.iloc[:,:].values.tolist() #store the values of the 3rd column from csv1 to a list
rate_out_1 = df2.iloc[:,:].values.tolist() #store the values of the 4th column from csv1 to a list

#rate_in_2 = df2.iloc[:,2].values.tolist() #store the values of the 3rd column from csv1 to a list
#rate_out_2 = df2.iloc[:,3].values.tolist() #store the values of the 4th column from csv1 to a list
for (x, y) in zip(rate_in_1, rate_out_1):
	print(max(x,y))
	break
	   

rate_in_total = [max(x,y) for (x, y) in zip(rate_in_1, rate_out_1)] # add the values of 2 rate in lists into rate_in_total list
#rate_out_total = [x+y for x, y in zip(rate_out_1, rate_out_2] # add the values of 2 rate out lists into rate_out_total list

#print(rate_in_total[1])
#Now to output/concatenate this into 1 DataFrame:

final_df = pd.DataFrame(rate_in_total)
print("shape of final_df", final_df.shape)

#final_df['Node'] = ['allnode' for x in rate_in_total]
#final_df['Link'] = df1.iloc[:,1].values.tolist()
#final_df = rate_in_total
#final_df['rate-out'] = rate_out_total
with open('csv/NVGestures/2/ir+depth_revwo.csv', 'a', newline='') as csvfile:
	final_df.to_csv(csvfile,sep=",",header=False, index=False)
#print(np.where(max(rate_in_total[1])))

#print(len(rate_in_total))
c=0
for x in range(len(rate_in_total)):
	#print(type(rate_in_total[x]))
	#print(max(rate_in_total[x]))
	# print(np.argmax(rate_in_total[x], axis=0))
	if np.argmax(rate_in_total[x], axis=0)==o1[x]:
		c +=1
print( c / 482)

##swith open('csv/Briareo/original.csv', 'a', newline='') as csvfile:
